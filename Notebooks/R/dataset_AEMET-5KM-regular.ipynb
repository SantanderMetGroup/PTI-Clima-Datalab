# %% [markdown]
# # PTI-Clima Notebooks  <img src="https://www.r-project.org/logo/Rlogo.png" alt="Description" width="60" height="40">
#
# ***
#
# > Este cuaderno o notebook muestra LO QUE MUESTRE EL NOTEBOOK utilizando los conjuntos de datos de la PTI-Clima que se incluyen en el [almacén de datos](https://pti.climate.ifca.es/data). Este trabajo está licenciado bajo una [Licencia Creative Commons Atribución 4.0 Internacional](http://creativecommons.org/licenses/by/4.0).
# >
# > ![Licencia de Creative Commons](https://i.creativecommons.org/l/by/4.0/88x31.png)

# %% [markdown]
# ## Guía para el uso del dataset: AEMET-5KM-regular
#
# **M. Fuente-González** (Instituto de Física de Cantabria, CSIC-Universidad de Cantabria, Santander, Spain).
#
# **¡Bienvenidos al cuaderno "Guía para el uso del dataset: AEMET-5KM-regular" de la Plataforma Virtual de Cálculo de la PTI-Clima!**
# Esta guía tiene como objetivo ayudarte a entender y cargar el dataset AEMET-5KM-regular, de manera que puedas sacar el máximo provecho de estos datos disponibles en el [**Almacén de Datos de la PTI-Clima**](https://pti.climate.ifca.es/data). A través de esta plataforma, podrás realizar investigaciones y **análisis climáticos de relevancia**, ya que ofrece **acceso transparente a una amplia gama de materiales y datos** subyacentes a los **servicios climáticos desarrollados en la PTI-Clima**, fomentando su **reutilización** y posibilitando la **reproducibilidad** de los productos generados.
#
# En concreto, esta guía pretende ayudarte a entender como cargar un dataset para usar las diferentes variables en diferentes tipos de estudios, ya sea el cálculo de índices, análisis climáticos, etc. El objetivo principal es que comprendas de forma general la carga de datos y que puedas llevarlo a cabo en tus propias investigaciones. Se trata de un cuaderno que contiene conceptos básicos para poder entender y reproducir otros de manera más autodidácta. De esta manera vamos a **guiarte** a través de los pasos fundamentales para trabajar de manera efectiva con los datos este tipo de daatasets.
#
# Tras la carga de datos, habrá bloques de visualizaciones, permitiendo familiarizarte con este tipo de análisis de resultados y permitiendote aprender diferentes tipos de representacionse. Para todo ello, se utilizará el **framework *climate4R***, un conjunto de librerías de R para la carga, post-procesamiento y análisis de datos climáticos.
#
#
# <img src="https://raw.githubusercontent.com/SantanderMetGroup/climate4R/refs/heads/devel/man/figures/climate4R_logo.svg" alt="Description" width="60" height="40">
#
# ***climate4R*** ofrece más funcionalidades de las que se ilustran en este notebook, como **funcionalidades de operaciones espaciales y temporales** o como **interpolación, subsetting o intersección espacial**. Además, brinda funcionalidades para la **corrección de sesgo y downscaling** o funciones específicas para el **cálculo de índices**. Consulta [Iturbide et al., 2019](https://www.sciencedirect.com/science/article/pii/S1364815218303049?via%3Dihub) y el repositorio de [github de climate4R](https://github.com/SantanderMetGroup/climate4R) para más información.

# %% [markdown]
# ### Contenido de este cuaderno
# 1) Carga de librerías
# 2) Selección de conjuntos de datos
# 3) Carga de datos
# 4) Análisis básico
#    * 4.1. Medias climatológicas
#    * 4.2. Percentiles
#    * 4.3. Índices
#    * 4.4. Precipitación
#    * 4.5. Series temporales

# %% [markdown]
# Empezamos dando la memoria que queramos a la RAM (la suficiente para poder cargar varios variables)

# %%
options(java.parameters = "-Xmx13g")

# %% [markdown]
# ### 1. Carga de librerías

# %% [markdown]
# Cargamos las librerías necesarias, que corresponden a librerías del framework *climate4R* y van a permitir cargar datos, transformarlos, usar índices y visualizarlos.

# %%
library(loadeR)
library(transformeR)
library(climate4R.indices)
library(visualizeR)
# Out:
# Loading required package: rJava
#
# Loading required package: loadeR.java
#
# Java version 24x amd64 by Azul Systems, Inc. detected
#
# The maximum JVM heap space available is: 13.00 GB
#
# NetCDF Java Library Version: 4.6.0-SNAPSHOT (Built-On: 20150423.1338) loaded and ready
#
# You can manually set the NetCDF Java Library version before loading the package:
# options(loadeR.java_forced_version = "X.Y.Z")
# library(loadeR.java)
#
# netCDF-Java CLASSPATH from bundled java package directory: C:/Users/Miriam/miniconda3/envs/rclima/lib/R/library/loadeR.java/java;C:/Users/Miriam/miniconda3/envs/rclima/lib/R/library/loadeR.java/java/netcdfAll-4.6.0-SNAPSHOT.jar
#
# Loading required package: climate4R.UDG
#
# climate4R.UDG version 0.2.6 (2023-06-26) is loaded
#
# Please use 'citation("climate4R.UDG")' to cite this package.
#
# loadeR version 1.8.4.9000 (2025-08-07) is loaded
#
# Please use 'citation("loadeR")' to cite this package.
#     _______   ____  ___________________  __  ________
#    / ___/ /  / /  |/  / __  /_  __/ __/ / / / / __  /
#   / /  / /  / / /|_/ / /_/ / / / / __/ / /_/ / /_/_/
#  / /__/ /__/ / /  / / __  / / / / /__ /___  / / \ \
#  \___/____/_/_/  /_/_/ /_/ /_/  \___/    /_/\/   \_\
#
#       github.com/SantanderMetGroup/climate4R
# transformeR version 2.2.3 (2024-06-05) is loaded
#
# Please see 'citation("transformeR")' to cite this package.
#
# climate4R.indices version 0.3.1 (2023-06-22) is loaded
#
# Use 'indexShow()' for an overview of the available climate indices and circIndexShow() for the circulation indices.
#
# NOTE: use package climate4R.climdex to calculate ETCCDI indices.
#
#
# Attaching package: 'climate4R.indices'
#
#
# The following object is masked from 'package:transformeR':
#
#     lambWT
#
#
# visualizeR version 1.6.4 (2023-10-26) is loaded
#
# Please see 'citation("visualizeR")' to cite this package.

# %% [markdown]
# ### 2. Selección de conjuntos de datos

# %% [markdown]
# Leemos el archivo donde se tiene el contenido de todos los datasets y vemos que pinta tiene para decidir que es lo que queremos cargar.

# %%
df <- read.csv("../data_inventory.csv")

# %%
head(df)
# Out:
#   dataset                      type         access  source            provider
# 1 AEMET-5KM-regular_Iberia_day observations opendap AEMET-5KM-regular
# 2 CHELSA-W5E5v1.0_Canarias_day observations opendap CHELSA-W5E5v1.0
# 3 CHELSA-W5E5v1.0_Iberia_day   observations opendap CHELSA-W5E5v1.0
# 4 PTI-grid-v0_Canarias_day     observations opendap PTI-grid-v0
# 5 PTI-grid-v0_Iberia_day       observations opendap PTI-grid-v0
# 6 PTI-grid-v1_Canarias_day     observations opendap PTI-grid-v1
#   experiment frequency
# 1            day
# 2            day
# 3            day
# 4            day
# 5            day
# 6            day
#   endpoint
# 1 https://hub.climate4r.ifca.es/thredds/dodsC/pti-clima/ncmls/OBSERVATIONS/AEMET-5KM-regular/Iberia/day/AEMET-5KM-regular_Iberia_day.ncml
# 2 https://hub.climate4r.ifca.es/thredds/dodsC/pti-clima/ncmls/OBSERVATIONS/CHELSA-W5E5v1.0/Canarias/day/CHELSA-W5E5v1.0_Canarias_day.ncml
# 3 https://hub.climate4r.ifca.es/thredds/dodsC/pti-clima/ncmls/OBSERVATIONS/CHELSA-W5E5v1.0/Iberia/day/CHELSA-W5E5v1.0_Iberia_day.ncml
# 4 https://hub.climate4r.ifca.es/thredds/dodsC/pti-clima/ncmls/OBSERVATIONS/PTI-grid-v0/Canarias/day/PTI-grid-v0_Canarias_day.ncml
# 5 https://hub.climate4r.ifca.es/thredds/dodsC/pti-clima/ncmls/OBSERVATIONS/PTI-grid-v0/Iberia/day/PTI-grid-v0_Iberia_day.ncml
# 6 https://hub.climate4r.ifca.es/thredds/dodsC/pti-clima/ncmls/OBSERVATIONS/PTI-grid-v1/Canarias/day/PTI-grid-v1_Canarias_day.ncml
#   dictionary
# 1 ../../Harmonization_dictionaries/AEMET-5KM-regular.dic
# 2 ../../Harmonization_dictionaries/CHELSA-W5E5v1.0.dic
# 3 ../../Harmonization_dictionaries/CHELSA-W5E5v1.0.dic
# 4 ../../Harmonization_dictionaries/PTI-grid-v0.dic
# 5 ../../Harmonization_dictionaries/PTI-grid-v0.dic
# 6 ../../Harmonization_dictionaries/PTI-grid-v1.dic

# %% [markdown]
# En este caso, vamos a cargar el dataset de AEMET-5KM-regular. Para ello, mostramos el subconjunto de los datasets que corresponden con *"AEMET-5KM-regular"*.

# %%
subset(df, source == "AEMET-5KM-regular")
# Out:
#   dataset                      type         access  source            provider
# 1 AEMET-5KM-regular_Iberia_day observations opendap AEMET-5KM-regular
#   experiment frequency
# 1            day
#   endpoint
# 1 https://hub.climate4r.ifca.es/thredds/dodsC/pti-clima/ncmls/OBSERVATIONS/AEMET-5KM-regular/Iberia/day/AEMET-5KM-regular_Iberia_day.ncml
#   dictionary
# 1 ../../Harmonization_dictionaries/AEMET-5KM-regular.dic

# %% [markdown]
# ### 3. Carga de datos

# %% [markdown]
# ##### Trabajamos con observaciones de la Península Ibérica

# %% [markdown]
# En este caso, solo se tiene un dataset que coincida con AEMET-5KM-regular, se trata de un dataset de observaciones correspondiente a los datos de la Península Ibérica, AEMET-5KM-regular_Iberia_day.

# %% [markdown]
# Primero llamamos al dataset concreto que queremos analizar, apuntando con el sufijo *endpoint*, a la url que queremos referirnos. A continuación, hacemos un inventario para saber que variables tiene el dataset y en que unidades están.

# %%
subset.pi <- subset(df, dataset == "AEMET-5KM-regular_Iberia_day")
lon.pi <- as.character(subset.pi$endpoint)
obs.pi <- dataInventory(lon.pi)
# Out:
# [2025-09-29 13:01:03.914555] Doing inventory ...
#
# [2025-09-29 13:01:04.448212] Opening dataset...
#
# [2025-09-29 13:01:06.724152] The dataset was successfuly opened
#
# [2025-09-29 13:01:07.272912] Retrieving info for 'tasmax' (2 vars remaining)
#
# [2025-09-29 13:01:07.508383] Retrieving info for 'pr' (1 vars remaining)
#
# [2025-09-29 13:01:07.556919] Retrieving info for 'tasmin' (0 vars remaining)
#
# [2025-09-29 13:01:07.638524] Done.

# %%
str(obs.pi)
# Out:
# List of 3
#  $ tasmax:List of 7
#   ..$ Description: chr "temperature"
#   ..$ DataType   : chr "float"
#   ..$ Shape      : int [1:3] 26298 170 273
#   ..$ Units      : chr "C"
#   ..$ DataSizeMb : num 4882
#   ..$ Version    : logi NA
#   ..$ Dimensions :List of 3
#   .. ..$ time:List of 4
#   .. .. ..$ Type      : chr "Time"
#   .. .. ..$ TimeStep  : chr "1.0 days"
#   .. .. ..$ Units     : chr "days since 1951-01-01 00:00:00"
#   .. .. ..$ Date_range: chr "1951-01-01T00:00:00Z - 2022-12-31T00:00:00Z"
#   .. ..$ lat :List of 5
#   .. .. ..$ Type       : chr "Lat"
#   .. .. ..$ Units      : chr "degrees_north"
#   .. .. ..$ Values     : num [1:170] 35.3 35.3 35.4 35.4 35.5 ...
#   .. .. ..$ Shape      : int 170
#   .. .. ..$ Coordinates: chr "lat"
#   .. ..$ lon :List of 5
#   .. .. ..$ Type       : chr "Lon"
#   .. .. ..$ Units      : chr "degrees_east"
#   .. .. ..$ Values     : num [1:273] -9.32 -9.27 -9.22 -9.17 -9.12 ...
#   .. .. ..$ Shape      : int 273
#   .. .. ..$ Coordinates: chr "lon"
#  $ pr    :List of 7
#   ..$ Description: chr "precipitation amount"
#   ..$ DataType   : chr "float"
#   ..$ Shape      : int [1:3] 26298 170 273
#   ..$ Units      : chr "kg m-2"
#   ..$ DataSizeMb : num 4882
#   ..$ Version    : logi NA
#   ..$ Dimensions :List of 3
#   .. ..$ time:List of 4
#   .. .. ..$ Type      : chr "Time"
#   .. .. ..$ TimeStep  : chr "1.0 days"
#   .. .. ..$ Units     : chr "days since 1951-01-01 00:00:00"
#   .. .. ..$ Date_range: chr "1951-01-01T00:00:00Z - 2022-12-31T00:00:00Z"
#   .. ..$ lat :List of 5
#   .. .. ..$ Type       : chr "Lat"
#   .. .. ..$ Units      : chr "degrees_north"
#   .. .. ..$ Values     : num [1:170] 35.3 35.3 35.4 35.4 35.5 ...
#   .. .. ..$ Shape      : int 170
#   .. .. ..$ Coordinates: chr "lat"
#   .. ..$ lon :List of 5
#   .. .. ..$ Type       : chr "Lon"
#   .. .. ..$ Units      : chr "degrees_east"
#   .. .. ..$ Values     : num [1:273] -9.32 -9.27 -9.22 -9.17 -9.12 ...
#   .. .. ..$ Shape      : int 273
#   .. .. ..$ Coordinates: chr "lon"
#  $ tasmin:List of 7
#   ..$ Description: chr "temperature"
#   ..$ DataType   : chr "float"
#   ..$ Shape      : int [1:3] 26298 170 273
#   ..$ Units      : chr "C"
#   ..$ DataSizeMb : num 4882
#   ..$ Version    : logi NA
#   ..$ Dimensions :List of 3
#   .. ..$ time:List of 4
#   .. .. ..$ Type      : chr "Time"
#   .. .. ..$ TimeStep  : chr "1.0 days"
#   .. .. ..$ Units     : chr "days since 1951-01-01 00:00:00"
#   .. .. ..$ Date_range: chr "1951-01-01T00:00:00Z - 2022-12-31T00:00:00Z"
#   .. ..$ lat :List of 5
#   .. .. ..$ Type       : chr "Lat"
#   .. .. ..$ Units      : chr "degrees_north"
#   .. .. ..$ Values     : num [1:170] 35.3 35.3 35.4 35.4 35.5 ...
#   .. .. ..$ Shape      : int 170
#   .. .. ..$ Coordinates: chr "lat"
#   .. ..$ lon :List of 5
#   .. .. ..$ Type       : chr "Lon"
#   .. .. ..$ Units      : chr "degrees_east"
#   .. .. ..$ Values     : num [1:273] -9.32 -9.27 -9.22 -9.17 -9.12 ...
#   .. .. ..$ Shape      : int 273
#   .. .. ..$ Coordinates: chr "lon"

# %% [markdown]
# Vamos a cargar la temperatura máxima diaria, que como se puede ver al hacer el inventario, hay que referirse a ella como *tasmax*. De todo el posible periodo que se tiene (1961-2022) vamos a cargar una región en específico (correspondiente a la parte norte de la Península Ibérica) y el periodo desde el 2000 al 2010.

# %%
tasmax.pi <- loadGridData(dataset = lon.pi,
                           var = "tasmax",
                           lonLim=c(-7.4,-2.7),
                           latLim=c(41.9, 43.9),
                           years=2000:2010)
# Out:
# [2025-09-29 13:01:07.976817] Opening dataset...
#
# [2025-09-29 13:01:08.584527] The dataset was successfuly opened
#
# [2025-09-29 13:01:08.588121] Defining geo-location parameters
#
# [2025-09-29 13:01:08.673163] Defining time selection parameters
#
# [2025-09-29 13:01:08.886875] Retrieving data subset ...
#
# [2025-09-29 13:01:18.830026] Done

# %% [markdown]
# Volvemos a llamar a la funcion *str* para ver la pinta que tiene la temperatura máxima, con esto podemos ver la resolución del dataset, unidades (en caso de no habernos fijado antes), etc.

# %%
str(tasmax.pi)
# Out:
# List of 4
#  $ Variable:List of 2
#   ..$ varName: chr "tasmax"
#   ..$ level  : NULL
#   ..- attr(*, "use_dictionary")= logi FALSE
#   ..- attr(*, "description")= chr "temperature"
#   ..- attr(*, "units")= chr "C"
#   ..- attr(*, "longname")= chr "tasmax"
#   ..- attr(*, "daily_agg_cellfun")= chr "none"
#   ..- attr(*, "monthly_agg_cellfun")= chr "none"
#   ..- attr(*, "verification_time")= chr "none"
#  $ Data    : num [1:4018, 1:37, 1:95] 8.95 8.42 8.25 5.88 6.77 ...
#   ..- attr(*, "dimensions")= chr [1:3] "time" "lat" "lon"
#  $ xyCoords:List of 2
#   ..$ x: num [1:95] -7.42 -7.37 -7.32 -7.27 -7.22 ...
#   ..$ y: num [1:37] 41.9 42 42 42.1 42.1 ...
#   ..- attr(*, "projection")= chr "LatLonProjection"
#   ..- attr(*, "resX")= num 0.05
#   ..- attr(*, "resY")= num 0.05
#  $ Dates   :List of 2
#   ..$ start: chr [1:4018] "2000-01-01 00:00:00 GMT" "2000-01-02 00:00:00 GMT" "2000-01-03 00:00:00 GMT" "2000-01-04 00:00:00 GMT" ...
#   ..$ end  : chr [1:4018] "2000-01-01 00:00:00 GMT" "2000-01-02 00:00:00 GMT" "2000-01-03 00:00:00 GMT" "2000-01-04 00:00:00 GMT" ...
#  - attr(*, "dataset")= chr "https://hub.climate4r.ifca.es/thredds/dodsC/pti-clima/ncmls/OBSERVATIONS/AEMET-5KM-regular/Iberia/day/AEMET-5KM"| __truncated__
#  - attr(*, "R_package_desc")= chr "loadeR-v1.8.4.9000"
#  - attr(*, "R_package_URL")= chr "https://github.com/SantanderMetGroup/loadeR"
#  - attr(*, "R_package_ref")= chr "https://doi.org/10.1016/j.envsoft.2018.09.009"

# %% [markdown]
# Podemos observar, que este dataset corresponde con la temperatura máxima y en el atributo "units" vemos que está en grados Celsius. Tiene una resolución de 0.05, es decir de unos 5 km aproximadamente y los datos son diarios. Como se ha elegido un un periodo concreto de tiempo (de 2000 a 2010) y de espacio (latitud de 41.9 a 43.9 y longitud de -7.4 a -2.7), las dimensiones y tamaño corresponden con este subconjunto.

# %% [markdown]
# ### 4. Análisis

# %% [markdown]
# #### 4.1. Media climatológica

# %% [markdown]
# Una vez tenemos el dataset cargado, pasamos a la parte de *visualización*. Para ello, una de las opciones es hacer una climatología y representarlo espacialmente. La función *spatialPlot*, permite realizar esta representación y dependiendo de los argumentos que se pasen, puedes modifcar el colorbar, añadir títulos, nombres a los ejes, etc.

# %%
spatialPlot(climatology(tasmax.pi), main="Promedio de la Temperatura Máxima", backdrop.theme="coastline", color.theme="YlOrRd", 
            colorkey = list(space = "right",
                            title = list("º C", cex = 1)
                           ),
            xlab = "Longitud",
            ylab = "Latitud"
            )
# Out:
# [2025-09-29 13:01:19.120221] - Computing climatology...
#
# [2025-09-29 13:01:19.624914] - Done.
# plot without title

# %% [markdown]
# #### 4.2. Percentiles

# %% [markdown]
# En vez del promedio, también podemos ver las colas de la distribución, como el percentil 90. Para ello, se le pasa a la función *climatology* dentro del argumento clim.fun lo que queremos que se haga.

# %%
p90.tmax <- climatology(tasmax.pi, clim.fun = list(FUN = "quantile", probs=0.90, na.rm=TRUE))
# Out:
# [2025-09-29 13:01:20.077999] - Computing climatology...
#
# [2025-09-29 13:01:21.073314] - Done.

# %%
spatialPlot(p90.tmax, main="Percentil 90 Temperatura Máxima", backdrop.theme="coastline", color.theme="YlOrRd", 
            colorkey = list(space = "right",
                            title = list("º C", cex = 1)),
                            xlab = "Longitud",
                            ylab = "Latitud"
                           
            )
# Out:
# plot without title

# %% [markdown]
# O el percentil 10.

# %%
p10.tmax <- climatology(tasmax.pi, clim.fun = list(FUN = "quantile", probs=0.10, na.rm=TRUE))
# Out:
# [2025-09-29 13:01:21.488213] - Computing climatology...
#
# [2025-09-29 13:01:22.298821] - Done.

# %%
spatialPlot(p10.tmax, main="Percentil 10 Temperatura Máxima", backdrop.theme="coastline", color.theme="YlOrRd", 
            colorkey = list(space = "right",
                            title = list("º C", cex = 1)),
                            xlab = "Longitud",
                            ylab = "Latitud"
                           
            )
# Out:
# plot without title

# %% [markdown]
# #### 4.3. Índices

# %% [markdown]
# Al igual que parámetros estadísticos, también podemos mirar índices. En este caso, vamos a ver cuántos días del año en cada gridbox se da que la temperatura esté por encima de 35 ºC. Para eso usamos la función *indexGrid* y sumamos los días del periodo con *sum* usando la función *climatology*

# %%
idx35 <- indexGrid(tx=tasmax.pi, index.code="TXth", th=35)
# Out:
# [2025-09-29 13:01:23.522393] Calculating TXth ...
#
# [2025-09-29 13:01:24.453598] Done

# %%
sum.idx35 <- climatology(idx35, clim.fun = list(FUN = "sum"))
# Out:
# [2025-09-29 13:01:24.484311] - Computing climatology...
#
# [2025-09-29 13:01:24.488881] - Done.

# %% [markdown]
# Es necesario, que una vez sumamos los días, pasarle una máscara de tierra. Por eso, primero creamos la máscara y a continuación, con la función *gridArithmetics* la aplicamos.

# %%
mask <- climatology(tasmax.pi)
mask$Data[!is.na(mask$Data)] <- 1
# Out:
# [2025-09-29 13:01:24.595706] - Computing climatology...
#
# [2025-09-29 13:01:24.963953] - Done.

# %%
idx35.masked <- gridArithmetics(sum.idx35, mask, operator="*")

# %%
spatialPlot(idx35.masked, main="Nº Días Tmax > 35 ºC", backdrop.theme="coastline", color.theme="YlOrRd", 
            colorkey = list(space = "right",
                            title = list("Nº Días", cex = 1)),
                            xlab = "Longitud",
                            ylab = "Latitud"
                           
            )
# Out:
# plot without title

# %% [markdown]
# #### 4.4. Precipitación

# %% [markdown]
# No solo se puede cargar la variable de temperatura máxima. Como hemos visto antes al ver las variables del dataset, también se tienen tiene temperatura mínima y precipitación. A continuación, cargaremos la precipitación, para ello nos referimos a ella como *pr*. Cargamos la misma región y el mismo periodo.

# %%
pr.pi <- loadGridData(dataset = lon.pi,
                           var = "pr",
                           lonLim=c(-7.4,-2.7),
                           latLim=c(41.9, 43.9),
                           years=2000:2010)
# Out:
# [2025-09-29 13:01:25.709008] Opening dataset...
#
# [2025-09-29 13:01:26.390239] The dataset was successfuly opened
#
# [2025-09-29 13:01:26.397101] Defining geo-location parameters
#
# [2025-09-29 13:01:26.433186] Defining time selection parameters
#
# [2025-09-29 13:01:26.614572] Retrieving data subset ...
#
# [2025-09-29 13:01:36.93185] Done

# %%
str(pr.pi)
# Out:
# List of 4
#  $ Variable:List of 2
#   ..$ varName: chr "pr"
#   ..$ level  : NULL
#   ..- attr(*, "use_dictionary")= logi FALSE
#   ..- attr(*, "description")= chr "precipitation amount"
#   ..- attr(*, "units")= chr "kg m-2"
#   ..- attr(*, "longname")= chr "pr"
#   ..- attr(*, "daily_agg_cellfun")= chr "none"
#   ..- attr(*, "monthly_agg_cellfun")= chr "none"
#   ..- attr(*, "verification_time")= chr "none"
#  $ Data    : num [1:4018, 1:37, 1:95] 0.000749 0.000749 0.006671 0 0.016032 ...
#   ..- attr(*, "dimensions")= chr [1:3] "time" "lat" "lon"
#  $ xyCoords:List of 2
#   ..$ x: num [1:95] -7.42 -7.37 -7.32 -7.27 -7.22 ...
#   ..$ y: num [1:37] 41.9 42 42 42.1 42.1 ...
#   ..- attr(*, "projection")= chr "LatLonProjection"
#   ..- attr(*, "resX")= num 0.05
#   ..- attr(*, "resY")= num 0.05
#  $ Dates   :List of 2
#   ..$ start: chr [1:4018] "2000-01-01 00:00:00 GMT" "2000-01-02 00:00:00 GMT" "2000-01-03 00:00:00 GMT" "2000-01-04 00:00:00 GMT" ...
#   ..$ end  : chr [1:4018] "2000-01-01 00:00:00 GMT" "2000-01-02 00:00:00 GMT" "2000-01-03 00:00:00 GMT" "2000-01-04 00:00:00 GMT" ...
#  - attr(*, "dataset")= chr "https://hub.climate4r.ifca.es/thredds/dodsC/pti-clima/ncmls/OBSERVATIONS/AEMET-5KM-regular/Iberia/day/AEMET-5KM"| __truncated__
#  - attr(*, "R_package_desc")= chr "loadeR-v1.8.4.9000"
#  - attr(*, "R_package_URL")= chr "https://github.com/SantanderMetGroup/loadeR"
#  - attr(*, "R_package_ref")= chr "https://doi.org/10.1016/j.envsoft.2018.09.009"

# %% [markdown]
# Las unidades de esta variable son kg·m^-2, no es necesario hacer ningún tipo de conversión si estamos acostumbrados a trabajar en mm/día, ya que es equivalente. Para proceder de forma distinta y ver otras funcionalidades del framework y como tratar el dataset, vamos a hacer una agregación mensual.

# %%
pr.pi.aggr.m <- aggregateGrid(pr.pi, aggr.m=list(FUN="sum"))
# Out:
# [2025-09-29 13:01:37.097099] Performing monthly aggregation...
#
# [2025-09-29 13:01:38.184924] Done.

# %% [markdown]
# Para una visualización espacial, recurrimos de nuevo a la función *spatialPlot*.

# %%
spatialPlot(climatology(pr.pi.aggr.m), main="Promedio de la precicipitación acumulada mensual", backdrop.theme="coastline", color.theme="Blues", 
            colorkey = list(space = "right",
                            title = list("mm/mes", cex = 1)
                           ),
            xlab = "Longitud",
            ylab = "Latitud"
            )
# Out:
# [2025-09-29 13:01:38.227333] - Computing climatology...
# [2025-09-29 13:01:38.270586] - Done.
# plot without title

# %% [markdown]
# #### 4.5. Series temporales

# %% [markdown]
# Elegimos varios puntos de la región de la península cargada. Para ver las diferencias se escoge Burgos, Santander y Oviedo. De esta manera, al usar la función *subsetGrid*, nos quedamos unicamente con la latitud y longitud seleccionadas.

# %%
burgos <- subsetGrid(pr.pi.aggr.m, latLim=42.3, lonLim=-3.7)
santander <- subsetGrid(pr.pi.aggr.m, latLim=43.5, lonLim=-3.8)
oviedo <- subsetGrid(pr.pi.aggr.m, latLim=43.3, lonLim=-5.8)

# %% [markdown]
# Usando la funcion *temporalGrid* podemos visualizar las series temporales de la precipitación acumulada mensual tanto para los gridboxes seleccionados, como para una media de toda la región cargada.

# %%
options(repr.plot.width = 16, repr.plot.height = 5)

temporalPlot("Burgos" = burgos,
             "Santander" = santander,
             "Oviedo" = oviedo,
             "Media región cargada" = pr.pi.aggr.m, 
             cols = c("blue", "red", "darkgreen", "black"),
             xyplot.custom = list(
               main = "Series temporales precipitación mensual acumulada",
               ylab = "Precipitación (mm)",
               xlab = "Fecha",
               scales = list(
                 x = list(
                   at = seq(min(as.Date(burgos$Dates$start)),
                            max(as.Date(burgos$Dates$start)),
                            by = "6 months"),
                   labels = format(
                     seq(min(as.Date(burgos$Dates$start)),
                         max(as.Date(burgos$Dates$start)),
                         by = "6 months"),
                     "%m-%Y"
                   ),
                   rot = 45
                 )
               )
             ))
# Out:
# pad applied on the interval: month
#
# pad applied on the interval: month
#
# pad applied on the interval: month
#
# pad applied on the interval: month
# plot without title

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29 ucrt)
# Platform: x86_64-w64-mingw32/x64 (64-bit)
# Running under: Windows 11 x64 (build 22631)
#
# Matrix products: default
#
#
# locale:
# [1] LC_COLLATE=Spanish_Spain.utf8  LC_CTYPE=Spanish_Spain.utf8
# [3] LC_MONETARY=Spanish_Spain.utf8 LC_NUMERIC=C
# [5] LC_TIME=Spanish_Spain.utf8
#
# time zone: Europe/Madrid
# tzcode source: internal
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] visualizeR_1.6.4        climate4R.indices_0.3.1 transformeR_2.2.3
# [4] loadeR_1.8.4.9000       climate4R.UDG_0.2.6     loadeR.java_1.2.1.9000
# [7] rJava_1.0-11
#
# loaded via a namespace (and not attached):
#  [1] dotCall64_1.2           spam_2.11-1             convertR_0.2.1
#  [4] latticeExtra_0.6-31     lattice_0.22-7          vctrs_0.6.5
#  [7] mapplots_1.5.3          tools_4.3.3             bitops_1.0-9
# [10] generics_0.1.4          parallel_4.3.3          tibble_3.2.1
# [13] proxy_0.4-27            SpecsVerification_0.5-3 pkgconfig_2.0.3
# [16] data.table_1.17.0       RColorBrewer_1.1-3      uuid_1.2-1
# [19] lifecycle_1.0.4         compiler_4.3.3          farver_2.1.2
# [22] kohonen_3.0.12          deldir_2.0-4            fields_16.3.1
# [25] akima_0.6-3.4           repr_1.1.7              htmltools_0.5.8.1
# [28] maps_3.4.2.1            RCurl_1.98-1.17         pillar_1.11.1
# [31] crayon_1.5.3            MASS_7.3-60.0.1         boot_1.3-32
# [34] abind_1.4-8             vioplot_0.5.1           padr_0.6.3
# [37] verification_1.45       tidyselect_1.2.1        digest_0.6.37
# [40] dplyr_1.1.4             fastmap_1.2.0           grid_4.3.3
# [43] cli_3.6.4               magrittr_2.0.3          base64enc_0.1-3
# [46] sm_2.2-6.0              IRdisplay_1.1           withr_3.0.2
# [49] udunits2_0.13.2.1       scales_1.4.0            sp_2.2-0
# [52] IRkernel_1.3.2          jpeg_0.1-11             interp_1.1-6
# [55] pbdZMQ_0.3-13           RcppEigen_0.3.4.0.2     zoo_1.8-13
# [58] png_0.1-8               pbapply_1.7-4           evaluate_1.0.5
# [61] dtw_1.23-1              viridisLite_0.4.2       rlang_1.1.5
# [64] Rcpp_1.0.14             glue_1.8.0              easyVerification_0.4.5
# [67] CircStats_0.2-7         jsonlite_2.0.0          R6_2.6.1
