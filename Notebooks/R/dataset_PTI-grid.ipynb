# %% [markdown]
# ![Banner PTI Clima](https://raw.githubusercontent.com/SantanderMetGroup/PTI-Clima-Datalab/devel/aux/Banner-logos-PTIClima-ProyectoServiciosAEMET.png)
# # Datalab de la Plataforma Estatal de Servicios Climáticos
# ***
# > Los cuadernos (Jupyter Notebooks) incluidos en este Datalab muestran ejemplos prácticos para utilizar, transformar y visualizar los conjuntos de datos disponibles en el [almacén de datos](https://pti.climate.ifca.es/data) de la Plataforma Estatal de Servicios Climáticos.
# >
# > Este trabajo está licenciado bajo una [Licencia Creative Commons Atribución 4.0 Internacional](http://creativecommons.org/licenses/by/4.0).
# >
# > ![Licencia de Creative Commons](https://i.creativecommons.org/l/by/4.0/88x31.png)

# %% [markdown]
# ## Guía para el uso del dataset: PTI-Grid
#
# **M. Iturbide** (Instituto de Física de Cantabria, CSIC-Universidad de Cantabria, Santander, Spain).
#
# En este notebook verás cómo trabajar con el dataset PTI-Grid disponible en el Almacén de Datos de la Plataforma Estatal de Servicios Climáticos. Este notebook tiene como objetivo principal facilitar su reutilización y asegurar la reproducibilidad de los productos climáticos. La guía recorre los pasos esenciales para acceder a los datos, definir peticiones de carga, realizar transformaciones básicas y visualizar los resultados.
#
# La Plataforma Virtual de Cálculo ofrece, además, un **notebook de primeros pasos** y una **colección de notebooks temáticos** (p. ej., intercomparación de conjuntos de datos observacionales o cálculo de índices) que puedes consultar para ampliar el uso de las herramientas y profundizar en los análisis a partir de los datos disponibles en el Almacén.
#
# Todo el flujo de trabajo se realiza con ***climate4R***, un framework de librerías en R para la carga, el postprocesamiento y el análisis de datos climáticos.
#
# <img src="https://raw.githubusercontent.com/SantanderMetGroup/climate4R/refs/heads/devel/man/figures/climate4R_logo.svg" alt="Description" width="60" height="40">
#
# ***climate4R*** ofrece más funcionalidades de las que se ilustran en este notebook, como **funcionalidades de operaciones espaciales y temporales** o como **interpolación, subsetting o intersección espacial**. Además, brinda funcionalidades para la **corrección de sesgo y downscaling** o funciones específicas para el **cálculo del FWI**. Consulta [Iturbide et al., 2019](https://www.sciencedirect.com/science/article/pii/S1364815218303049?via%3Dihub) y el repositorio de [github de climate4R](https://github.com/SantanderMetGroup/climate4R) para más información.

# %% [markdown]
# ### Contenido de este cuaderno
# 1) Carga de librerías
# 2) Selección de conjuntos de datos
# 3) Carga de datos y visualización

# %% [markdown]
# Antes de empezar, o en cualquier momento durante el cuaderno, podemos personalizar el área de visualización de gráficos de la siguiente manera:

# %%
library(repr)
# Change plot size 
options(repr.plot.width=8, repr.plot.height=5)

# %% [markdown]
# Empezamos asignando a la JVM (Máquina Virtual de Java) la memoria que estimemos necesaria para la carga de datos que realizaremos.

# %%
options(java.parameters = "-Xmx10g")

# %% [markdown]
# ### 1. Carga de librerías
#
# Para las operaciones que se llevan a cabo en este notebook solo necesitaremos tres librerías de ***climate4R***: `loadeR` para la carga de datos, `transformeR` para calcular agregaciones temporales y extraer subconjuntos de información, y `visualizeR` para la representación gráfica de los resultados.

# %%
library(loadeR)
library(transformeR)
library(visualizeR)
# Out:
# Loading required package: rJava
#
# Loading required package: loadeR.java
#
# Java version 22x amd64 by N/A detected
#
# NetCDF Java Library v4.6.0-SNAPSHOT (23 Apr 2015) loaded and ready
#
# Loading required package: climate4R.UDG
#
# climate4R.UDG version 0.2.6 (2023-06-26) is loaded
#
# Please use 'citation("climate4R.UDG")' to cite this package.
#
# loadeR version 1.8.1 (2023-06-22) is loaded
#
# WARNING: Your current version of loadeR (v1.8.1) is not up-to-date
#
# Get the latest stable version (1.8.2) using <devtools::install_github(c('SantanderMetGroup/climate4R.UDG','SantanderMetGroup/loadeR'))>
#
# Please use 'citation("loadeR")' to cite this package.
#     _______   ____  ___________________  __  ________
#    / ___/ /  / /  |/  / __  /_  __/ __/ / / / / __  /
#   / /  / /  / / /|_/ / /_/ / / / / __/ / /_/ / /_/_/
#  / /__/ /__/ / /  / / __  / / / / /__ /___  / / \ \
#  \___/____/_/_/  /_/_/ /_/ /_/  \___/    /_/\/   \_\
#
#       github.com/SantanderMetGroup/climate4R
# transformeR version 2.2.2 (2023-10-26) is loaded
#
# WARNING: Your current version of transformeR (v2.2.2) is not up-to-date
#
# Get the latest stable version (2.2.5) using <devtools::install_github('SantanderMetGroup/transformeR')>
#
# Please see 'citation("transformeR")' to cite this package.
#
# visualizeR version 1.6.4 (2023-10-26) is loaded
#
# Please see 'citation("visualizeR")' to cite this package.

# %% [markdown]
# ### 2. Selección de conjuntos de datos

# %% [markdown]
# El inventario `data_inventory.csv` cataloga la lista de archivos del Almacén de datos de la PTI-Clima.
#
# Basta con leer este archivo mediante `read.csv` para obtener el `data.frame` que contiene esta información.

# %%
df <- read.csv("../../data_inventory.csv")

# %% [markdown]
# A continuación mostramos el cabecero del inventario.

# %%
head(df)
# Out:
#   dataset                              type         access
# 1 AEMET-ROCIO-IBEB-regular_Iberia_day  observations opendap
# 2 AEMET-ROCIO-CAN-regular_Canarias_day observations opendap
# 3 CHELSA-W5E5v1.0_Canarias_day         observations opendap
# 4 CHELSA-W5E5v1.0_Iberia_day           observations opendap
# 5 PTI-grid-v0_Canarias_day             observations opendap
# 6 PTI-grid-v0_Iberia_day               observations opendap
#   source                   provider experiment frequency
# 1 AEMET-ROCIO-IBEB-regular                     day
# 2 AEMET-ROCIO-CAN-regular                      day
# 3 CHELSA-W5E5v1.0                              day
# 4 CHELSA-W5E5v1.0                              day
# 5 PTI-grid-v0                                  day
# 6 PTI-grid-v0                                  day
#   endpoint
# 1 https://thredds.climate.ifca.es/thredds/dodsC/pti-clima/ncmls/OBSERVATIONS/AEMET-ROCIO-IBEB/Iberia/day/AEMET-ROCIO-IBEB_Iberia_day.ncml
# 2 https://thredds.climate.ifca.es/thredds/dodsC/pti-clima/ncmls/OBSERVATIONS/AEMET-ROCIO-CAN/Canarias/day/AEMET-ROCIO-CAN_Canarias_day.ncml
# 3 https://thredds.climate.ifca.es/thredds/dodsC/pti-clima/ncmls/OBSERVATIONS/CHELSA-W5E5v1.0/Canarias/day/CHELSA-W5E5v1.0_Canarias_day.ncml
# 4 https://thredds.climate.ifca.es/thredds/dodsC/pti-clima/ncmls/OBSERVATIONS/CHELSA-W5E5v1.0/Iberia/day/CHELSA-W5E5v1.0_Iberia_day.ncml
# 5 https://thredds.climate.ifca.es/thredds/dodsC/pti-clima/ncmls/OBSERVATIONS/PTI-grid-v0/Canarias/day/PTI-grid-v0_Canarias_day.ncml
# 6 https://thredds.climate.ifca.es/thredds/dodsC/pti-clima/ncmls/OBSERVATIONS/PTI-grid-v0/Iberia/day/PTI-grid-v0_Iberia_day.ncml
#   dictionary
# 1 ../../Harmonization_dictionaries/AEMET-ROCIO-regular.dic
# 2 ../../Harmonization_dictionaries/AEMET-ROCIO-regular.dic
# 3 ../../Harmonization_dictionaries/CHELSA-W5E5v1.0.dic
# 4 ../../Harmonization_dictionaries/CHELSA-W5E5v1.0.dic
# 5 ../../Harmonization_dictionaries/PTI-grid-v0.dic
# 6 ../../Harmonization_dictionaries/PTI-grid-v0.dic

# %% [markdown]
# Para encontrar fácilmente el dataset que nos interesa usaremos la función `subset`. Especificando `source == "PTI-grid"` obtenemos la lista de dos datasets, uno para la Península Ibérica (*Iberia*) y otro para las Islas Canarias (*Canarias*).

# %%
subset(df, source == "PTI-grid")
# Out:
#    dataset               type         access  source   provider experiment
# 13 PTI-grid_Canarias_day observations opendap PTI-grid
# 14 PTI-grid_Iberia_day   observations opendap PTI-grid
#    frequency
# 13 day
# 14 day
#    endpoint
# 13 https://thredds.climate.ifca.es/thredds/dodsC/pti-clima/ncmls/OBSERVATIONS/PTI-grid/Canarias/day/PTI-grid_Canarias_day.ncml
# 14 https://thredds.climate.ifca.es/thredds/dodsC/pti-clima/ncmls/OBSERVATIONS/PTI-grid/Iberia/day/PTI-grid_Iberia_day.ncml
#    dictionary
# 13 ../../Harmonization_dictionaries/PTI-grid-v1.dic
# 14 ../../Harmonization_dictionaries/PTI-grid-v1.dic

# %% [markdown]
# ### 3. Carga de datos y visualización

# %% [markdown]
# El inventario nos indica cuál es el `endpoint` de cada dataset. Es decir, el enlace que necesitamos utilizar para la carga de datos.

# %% [markdown]
# Primero concretamos el dataset que queremos analizar y extraemos el elemento *endpoint*. Empezaremos por la Península Ibérica.

# %%
dataset <- subset(df, dataset == "PTI-grid_Iberia_day")

# %%
endpoint <- dataset$endpoint

# %% [markdown]
# Antes de cargar los datos, conviene revisar el dataset con `dataInventory`. Esta función devuelve un resumen útil para entender qué información contiene y cómo está descrita (variables, unidades y cobertura temporal, entre otros aspectos).

# %%
di <- dataInventory(endpoint)
# Out:
# [2026-06-09 07:43:15.620019] Doing inventory ...
#
# [2026-06-09 07:43:15.96252] Opening dataset...
#
# [2026-06-09 07:43:17.100695] The dataset was successfuly opened
#
# [2026-06-09 07:43:17.239816] Retrieving info for 'tasmin' (6 vars remaining)
#
# [2026-06-09 07:43:17.339778] Retrieving info for 'tasmax' (5 vars remaining)
#
# [2026-06-09 07:43:17.463039] Retrieving info for 'ssrd' (4 vars remaining)
#
# [2026-06-09 07:43:17.536289] Retrieving info for 'wss' (3 vars remaining)
#
# [2026-06-09 07:43:17.623536] Retrieving info for 'pr' (2 vars remaining)
#
# [2026-06-09 07:43:17.69153] Retrieving info for 'hurs' (1 vars remaining)
#
# [2026-06-09 07:43:17.758869] Retrieving info for 'tdps' (0 vars remaining)
#
# [2026-06-09 07:43:17.83374] Done.

# %%
str(di)
# Out:
# List of 7
#  $ tasmin:List of 7
#   ..$ Description: chr "Minimum daily temperature"
#   ..$ DataType   : chr "float"
#   ..$ Shape      : int [1:3] 23799 342 545
#   ..$ Units      : chr "ºC"
#   ..$ DataSizeMb : num 17744
#   ..$ Version    : logi NA
#   ..$ Dimensions :List of 3
#   .. ..$ time     :List of 4
#   .. .. ..$ Type      : chr "Time"
#   .. .. ..$ TimeStep  : chr "1.0 days"
#   .. .. ..$ Units     : chr "days since 1970-01-01 00:00:00"
#   .. .. ..$ Date_range: chr "1961-01-01T01:00:00Z - 2026-02-27T01:00:00Z"
#   .. ..$ latitude :List of 5
#   .. .. ..$ Type       : chr "Lat"
#   .. .. ..$ Units      : chr "degrees_north"
#   .. .. ..$ Values     : num [1:342] 35.3 35.3 35.3 35.4 35.4 ...
#   .. .. ..$ Shape      : int 342
#   .. .. ..$ Coordinates: chr "latitude"
#   .. ..$ longitude:List of 5
#   .. .. ..$ Type       : chr "Lon"
#   .. .. ..$ Units      : chr "degrees_east"
#   .. .. ..$ Values     : num [1:545] -9.29 -9.26 -9.24 -9.21 -9.19 ...
#   .. .. ..$ Shape      : int 545
#   .. .. ..$ Coordinates: chr "longitude"
#  $ tasmax:List of 7
#   ..$ Description: chr "Maximum daily temperature"
#   ..$ DataType   : chr "float"
#   ..$ Shape      : int [1:3] 23799 342 545
#   ..$ Units      : chr "ºC"
#   ..$ DataSizeMb : num 17744
#   ..$ Version    : logi NA
#   ..$ Dimensions :List of 3
#   .. ..$ time     :List of 4
#   .. .. ..$ Type      : chr "Time"
#   .. .. ..$ TimeStep  : chr "1.0 days"
#   .. .. ..$ Units     : chr "days since 1970-01-01 00:00:00"
#   .. .. ..$ Date_range: chr "1961-01-01T01:00:00Z - 2026-02-27T01:00:00Z"
#   .. ..$ latitude :List of 5
#   .. .. ..$ Type       : chr "Lat"
#   .. .. ..$ Units      : chr "degrees_north"
#   .. .. ..$ Values     : num [1:342] 35.3 35.3 35.3 35.4 35.4 ...
#   .. .. ..$ Shape      : int 342
#   .. .. ..$ Coordinates: chr "latitude"
#   .. ..$ longitude:List of 5
#   .. .. ..$ Type       : chr "Lon"
#   .. .. ..$ Units      : chr "degrees_east"
#   .. .. ..$ Values     : num [1:545] -9.29 -9.26 -9.24 -9.21 -9.19 ...
#   .. .. ..$ Shape      : int 545
#   .. .. ..$ Coordinates: chr "longitude"
#  $ ssrd  :List of 7
#   ..$ Description: chr "Daily total global radiation"
#   ..$ DataType   : chr "float"
#   ..$ Shape      : int [1:3] 23799 342 545
#   ..$ Units      : chr "kJ m-2 day-1"
#   ..$ DataSizeMb : num 17744
#   ..$ Version    : logi NA
#   ..$ Dimensions :List of 3
#   .. ..$ time     :List of 4
#   .. .. ..$ Type      : chr "Time"
#   .. .. ..$ TimeStep  : chr "1.0 days"
#   .. .. ..$ Units     : chr "days since 1970-01-01 00:00:00"
#   .. .. ..$ Date_range: chr "1961-01-01T01:00:00Z - 2026-02-27T01:00:00Z"
#   .. ..$ latitude :List of 5
#   .. .. ..$ Type       : chr "Lat"
#   .. .. ..$ Units      : chr "degrees_north"
#   .. .. ..$ Values     : num [1:342] 35.3 35.3 35.3 35.4 35.4 ...
#   .. .. ..$ Shape      : int 342
#   .. .. ..$ Coordinates: chr "latitude"
#   .. ..$ longitude:List of 5
#   .. .. ..$ Type       : chr "Lon"
#   .. .. ..$ Units      : chr "degrees_east"
#   .. .. ..$ Values     : num [1:545] -9.29 -9.26 -9.24 -9.21 -9.19 ...
#   .. .. ..$ Shape      : int 545
#   .. .. ..$ Coordinates: chr "longitude"
#  $ wss   :List of 7
#   ..$ Description: chr "Mean daily wind speed"
#   ..$ DataType   : chr "float"
#   ..$ Shape      : int [1:3] 23799 342 545
#   ..$ Units      : chr "Km h-1"
#   ..$ DataSizeMb : num 17744
#   ..$ Version    : logi NA
#   ..$ Dimensions :List of 3
#   .. ..$ time     :List of 4
#   .. .. ..$ Type      : chr "Time"
#   .. .. ..$ TimeStep  : chr "1.0 days"
#   .. .. ..$ Units     : chr "days since 1970-01-01 00:00:00"
#   .. .. ..$ Date_range: chr "1961-01-01T01:00:00Z - 2026-02-27T01:00:00Z"
#   .. ..$ latitude :List of 5
#   .. .. ..$ Type       : chr "Lat"
#   .. .. ..$ Units      : chr "degrees_north"
#   .. .. ..$ Values     : num [1:342] 35.3 35.3 35.3 35.4 35.4 ...
#   .. .. ..$ Shape      : int 342
#   .. .. ..$ Coordinates: chr "latitude"
#   .. ..$ longitude:List of 5
#   .. .. ..$ Type       : chr "Lon"
#   .. .. ..$ Units      : chr "degrees_east"
#   .. .. ..$ Values     : num [1:545] -9.29 -9.26 -9.24 -9.21 -9.19 ...
#   .. .. ..$ Shape      : int 545
#   .. .. ..$ Coordinates: chr "longitude"
#  $ pr    :List of 7
#   ..$ Description: chr "Daily cumulative precipitation"
#   ..$ DataType   : chr "float"
#   ..$ Shape      : int [1:3] 23799 342 545
#   ..$ Units      : chr "mm day-1"
#   ..$ DataSizeMb : num 17744
#   ..$ Version    : logi NA
#   ..$ Dimensions :List of 3
#   .. ..$ time     :List of 4
#   .. .. ..$ Type      : chr "Time"
#   .. .. ..$ TimeStep  : chr "1.0 days"
#   .. .. ..$ Units     : chr "days since 1970-01-01 00:00:00"
#   .. .. ..$ Date_range: chr "1961-01-01T01:00:00Z - 2026-02-27T01:00:00Z"
#   .. ..$ latitude :List of 5
#   .. .. ..$ Type       : chr "Lat"
#   .. .. ..$ Units      : chr "degrees_north"
#   .. .. ..$ Values     : num [1:342] 35.3 35.3 35.3 35.4 35.4 ...
#   .. .. ..$ Shape      : int 342
#   .. .. ..$ Coordinates: chr "latitude"
#   .. ..$ longitude:List of 5
#   .. .. ..$ Type       : chr "Lon"
#   .. .. ..$ Units      : chr "degrees_east"
#   .. .. ..$ Values     : num [1:545] -9.29 -9.26 -9.24 -9.21 -9.19 ...
#   .. .. ..$ Shape      : int 545
#   .. .. ..$ Coordinates: chr "longitude"
#  $ hurs  :List of 7
#   ..$ Description: chr "Daily mean relative humidity, average of four synoptic measurements"
#   ..$ DataType   : chr "float"
#   ..$ Shape      : int [1:3] 23799 342 545
#   ..$ Units      : chr "%"
#   ..$ DataSizeMb : num 17744
#   ..$ Version    : logi NA
#   ..$ Dimensions :List of 3
#   .. ..$ time     :List of 4
#   .. .. ..$ Type      : chr "Time"
#   .. .. ..$ TimeStep  : chr "1.0 days"
#   .. .. ..$ Units     : chr "days since 1970-01-01 00:00:00"
#   .. .. ..$ Date_range: chr "1961-01-01T01:00:00Z - 2026-02-27T01:00:00Z"
#   .. ..$ latitude :List of 5
#   .. .. ..$ Type       : chr "Lat"
#   .. .. ..$ Units      : chr "degrees_north"
#   .. .. ..$ Values     : num [1:342] 35.3 35.3 35.3 35.4 35.4 ...
#   .. .. ..$ Shape      : int 342
#   .. .. ..$ Coordinates: chr "latitude"
#   .. ..$ longitude:List of 5
#   .. .. ..$ Type       : chr "Lon"
#   .. .. ..$ Units      : chr "degrees_east"
#   .. .. ..$ Values     : num [1:545] -9.29 -9.26 -9.24 -9.21 -9.19 ...
#   .. .. ..$ Shape      : int 545
#   .. .. ..$ Coordinates: chr "longitude"
#  $ tdps  :List of 7
#   ..$ Description: chr "Dew point temperature"
#   ..$ DataType   : chr "float"
#   ..$ Shape      : int [1:3] 23799 342 545
#   ..$ Units      : chr "ºC"
#   ..$ DataSizeMb : num 17744
#   ..$ Version    : logi NA
#   ..$ Dimensions :List of 3
#   .. ..$ time     :List of 4
#   .. .. ..$ Type      : chr "Time"
#   .. .. ..$ TimeStep  : chr "1.0 days"
#   .. .. ..$ Units     : chr "days since 1970-01-01 00:00:00"
#   .. .. ..$ Date_range: chr "1961-01-01T01:00:00Z - 2026-02-27T01:00:00Z"
#   .. ..$ latitude :List of 5
#   .. .. ..$ Type       : chr "Lat"
#   .. .. ..$ Units      : chr "degrees_north"
#   .. .. ..$ Values     : num [1:342] 35.3 35.3 35.3 35.4 35.4 ...
#   .. .. ..$ Shape      : int 342
#   .. .. ..$ Coordinates: chr "latitude"
#   .. ..$ longitude:List of 5
#   .. .. ..$ Type       : chr "Lon"
#   .. .. ..$ Units      : chr "degrees_east"
#   .. .. ..$ Values     : num [1:545] -9.29 -9.26 -9.24 -9.21 -9.19 ...
#   .. .. ..$ Shape      : int 545
#   .. .. ..$ Coordinates: chr "longitude"

# %% [markdown]
# Este resumen facilita definir la petición de carga de datos. En este ejemplo, cargamos la precipitación diaria (`pr`). Del periodo completo disponible (véase `Date_range` en el resumen del dataset), solicitaremos un intervalo de 20 años. La carga se realiza con la función `loadGridData`, que permite especificar otros parámetros además de la variable y el periodo; por ejemplo, podemos seleccionar una estación concreta o agregar los datos a escala mensual. En este caso, pedimos la media mensual de los meses de invierno (`c(12, 1:2)`). *NOTA: Esta operación puede tardar unos minutos cuando se trata de conjuntos de datos de alta resolución*.

# %%
pr <- loadGridData(dataset = endpoint,
                   var = "pr",
                   season = c(12, 1:2),
                   years = 1991:2010,
                   aggr.m = "mean")
# Out:
# [2026-06-09 07:43:24.568911] Opening dataset...
#
# [2026-06-09 07:43:24.734809] The dataset was successfuly opened
#
# [2026-06-09 07:43:24.742102] Defining geo-location parameters
#
# [2026-06-09 07:43:24.831785] Defining time selection parameters
#
# NOTE: Daily data will be monthly aggregated
#
# [2026-06-09 07:43:25.069683] Retrieving data subset ...
#
# [2026-06-09 08:05:41.646219] Done

# %% [markdown]
# El objeto resultante es lo que denominamos *grid de climate4R*. Se trata de una lista con los elementos "Variable", "Data", "xyCoords" y "Dates". Es posible extraer cada uno de estos componentes y transformarlos mediante operaciones básicas de R, sin embargo, las librerías de climate4R están diseñadas para trabajar de forma transparente con la estructura completa.

# %%
str(pr)
# Out:
# List of 4
#  $ Variable:List of 2
#   ..$ varName: chr "pr"
#   ..$ level  : NULL
#   ..- attr(*, "use_dictionary")= logi FALSE
#   ..- attr(*, "description")= chr "Daily cumulative precipitation"
#   ..- attr(*, "units")= chr "mm day-1"
#   ..- attr(*, "longname")= chr "pr"
#   ..- attr(*, "daily_agg_cellfun")= chr "none"
#   ..- attr(*, "monthly_agg_cellfun")= chr "mean"
#   ..- attr(*, "verification_time")= chr "none"
#  $ Data    : num [1:60, 1:342, 1:545] NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN ...
#   ..- attr(*, "dimensions")= chr [1:3] "time" "lat" "lon"
#  $ xyCoords:List of 2
#   ..$ x: num [1:545] -9.29 -9.26 -9.24 -9.21 -9.19 ...
#   ..$ y: num [1:342] 35.3 35.3 35.3 35.4 35.4 ...
#   ..- attr(*, "projection")= chr "LatLonProjection"
#   ..- attr(*, "resX")= num 0.025
#   ..- attr(*, "resY")= num 0.025
#  $ Dates   :List of 2
#   ..$ start: chr [1:60] "1990-12-01 GMT" "1991-01-01 GMT" "1991-02-01 GMT" "1991-12-01 GMT" ...
#   ..$ end  : chr [1:60] "1991-01-01 GMT" "1991-02-01 GMT" "1991-03-01 GMT" "1992-01-01 GMT" ...
#  - attr(*, "dataset")= chr "https://thredds.climate.ifca.es/thredds/dodsC/pti-clima/ncmls/OBSERVATIONS/PTI-grid/Iberia/day/PTI-grid_Iberia_day.ncml"
#  - attr(*, "R_package_desc")= chr "loadeR-v1.8.1"
#  - attr(*, "R_package_URL")= chr "https://github.com/SantanderMetGroup/loadeR"
#  - attr(*, "R_package_ref")= chr "https://doi.org/10.1016/j.envsoft.2018.09.009"

# %% [markdown]
# *climate4R* incluye múltiples funciones de transformación para agregar datos (temporal y espacialmente), extraer subconjuntos, modificar unidades, etc. A continuación se muestran algunos ejemplos.
#
# Para obtener el promedio temporal a lo largo de todo el periodo del grid, la función más directa es `climatology`.

# %%
pr.clim <- climatology(pr)
# Out:
# [2026-06-09 08:07:04.046983] - Computing climatology...
#
# [2026-06-09 08:07:05.526749] - Done.

# %% [markdown]
# Para agregar los datos anualmente usaremos `aggregateGrid` con el argumento `aggr.y`.

# %%
pr.annual <- aggregateGrid(pr, aggr.y = list(FUN = "mean", na.rm = T))
# Out:
# [2026-06-09 08:07:08.21509] Performing annual aggregation...
#
# [2026-06-09 08:07:38.531153] Done.

# %% [markdown]
# Para extraer localidades o subconjuntos espaciales usaremos `subsetGrid` definiendo los argumentos `lonLim` y `latLim`. Para extraer una subregión, `latLim` y `lonLim` se definen como vectores de dos elementos que definen los límites de la región de interés. En este ejemplo, extraemos la información para localidades puntuales, por lo tanto se asigna un único valor a `latLim` y a `lonLim`.

# %%
gasteiz <- subsetGrid(pr.annual, latLim = 42.85, lonLim = -2.67)
murcia  <- subsetGrid(pr.annual, latLim = 37.99, lonLim = -1.13)
lugo    <- subsetGrid(pr.annual, latLim = 43.01, lonLim = -7.56)

# %% [markdown]
# Las principales funciones de visualización son `temporalPlot` (series temporales) y `spatialPlot` (mapas).

# %%
temporalPlot("Gasteiz" = gasteiz, "Murcia" = murcia, "Lugo" = lugo,
             xyplot.custom = list(main = "Media invernal de la precipitación diaria (mm/día)"))
# Out:
# pad applied on the interval: year
#
# pad applied on the interval: year
#
# pad applied on the interval: year
# plot without title

# %%
spatialPlot(pr.clim,
            at             = seq(0, 7, 0.2),
            set.max        = 7,
            set.min        = 0,
            main           = "Promedio invernal de la precipitación diaria en el periodo 1991-2010",
            backdrop.theme = "coastline",
            color.theme    = "BrBG",
            colorkey       = list(space = "right",
                                  title = list("mm/día", cex = 1)),
            xlab           = "Longitud",
            ylab           = "Latitud")
# Out:
# plot without title

# %% [markdown]
# En lugar de la media podemos calcular cualquier otro estadístico con `climatology` definiendo la función de agregación (parámetro `clim.fun`), por ejemplo, podemos visualizar el percentil 90 utilizando previamente la función `quantile` (librería `stats` de R) en el cálculo de la climatología.

# %%
pr.clim.p90 <- climatology(pr, clim.fun = list(FUN = "quantile", probs = 0.90, na.rm = TRUE))
# Out:
# [2026-06-09 08:08:21.405259] - Computing climatology...
#
# [2026-06-09 08:08:43.287497] - Done.

# %%
spatialPlot(pr.clim.p90,
            at             = seq(0, 7, 0.2),
            set.max        = 7,
            set.min        = 0,
            main           = "Percentil 90 de la precipitación diaria en invierno y en el periodo 1991-2010",
            backdrop.theme = "coastline",
            color.theme    = "BrBG",
            colorkey       = list(space = "right",
                                  title = list("mm/día", cex = 1)),
            xlab           = "Longitud",
            ylab           = "Latitud")
# Out:
# plot without title

# %% [markdown]
# ----
# A continuación se repite parte del proceso visto anteriormente, considerando el dataset correspondiente a ***Canarias***. En este caso cargaremos la temperatura máxima de verano. Primero cargamos y transformamos los datos.

# %%
dataset.can  <- subset(df, dataset == "PTI-grid_Canarias_day")
endpoint.can <- dataset.can$endpoint

tasmax.can <- loadGridData(dataset = endpoint.can,
                           var     = "tasmax",
                           season  = 6:8,
                           years   = 1991:2010,
                           aggr.m  = "mean")

tasmax.can.clim  <- climatology(tasmax.can)
tasmax.can.anual <- aggregateGrid(tasmax.can, aggr.y = list(FUN = "mean", na.rm = T))
# Out:
# [2026-06-09 08:08:49.955783] Opening dataset...
#
# [2026-06-09 08:08:50.098916] The dataset was successfuly opened
#
# [2026-06-09 08:08:50.103298] Defining geo-location parameters
#
# [2026-06-09 08:08:50.202178] Defining time selection parameters
#
# NOTE: Daily data will be monthly aggregated
#
# [2026-06-09 08:08:50.353621] Retrieving data subset ...
#
# [2026-06-09 08:10:11.9676] Done
#
# [2026-06-09 08:10:11.975725] - Computing climatology...
#
# [2026-06-09 08:10:12.100404] - Done.
#
# [2026-06-09 08:10:12.113769] Performing annual aggregation...
#
# [2026-06-09 08:10:15.176188] Done.

# %% [markdown]
# A continuación visualizamos los resultados. En este ejemplo, en lugar de extraer localidades concretas de las islas, representaremos la serie correspondiente a la media regional de todas las islas. La función `temporalPlot` realiza esta agregación regional de manera automática.

# %%
temporalPlot("Canarias" = tasmax.can.anual)

spatialPlot(tasmax.can.clim,
            at       = seq(22, 34, 1),
            set.max  = 34,
            set.min  = 22,
            main     = "Promedio de la temperatura máxima de verano en el periodo 1991-2010",
            color.theme = "YlOrRd",
            colorkey = list(space = "right",
                            title = list("º C", cex = 1)),
            xlab     = "Longitud",
            ylab     = "Latitud")
# Out:
# pad applied on the interval: year
# plot without title
# plot without title

# %% [markdown]
# ***climate4R*** ofrece más funcionalidades de las que se ilustran en este notebook, como **funcionalidades de operaciones espaciales y temporales** o como **interpolación, subsetting o intersección espacial**. Además, brinda funcionalidades para la **corrección de sesgo y downscaling** o funciones específicas para el **cálculo del FWI**. Consulta [Iturbide et al., 2019](https://www.sciencedirect.com/science/article/pii/S1364815218303049?via%3Dihub) y el repositorio de [github de climate4R](https://github.com/SantanderMetGroup/climate4R) para más información.
#
# La Plataforma Virtual de Cálculo ofrece un **notebook de primeros pasos** y una **colección de notebooks temáticos** (p. ej., intercomparación de conjuntos de datos observacionales o cálculo de índices) que puedes consultar para ampliar el uso de las herramientas y profundizar en los análisis a partir de los datos disponibles en el Almacén.

# %% [markdown]
# ***
#
# ### Session Info

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Ubuntu 22.04.3 LTS
#
# Matrix products: default
# BLAS/LAPACK: /opt/conda/envs/climate4r/lib/libopenblasp-r0.3.28.so;  LAPACK version 3.12.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8          LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8           LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8       LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8          LC_NAME=en_US.UTF-8
#  [9] LC_ADDRESS=en_US.UTF-8        LC_TELEPHONE=en_US.UTF-8
# [11] LC_MEASUREMENT=en_US.UTF-8    LC_IDENTIFICATION=en_US.UTF-8
#
# time zone: Etc/UTC
# tzcode source: system (glibc)
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] visualizeR_1.6.4    transformeR_2.2.2   loadeR_1.8.1
# [4] climate4R.UDG_0.2.6 loadeR.java_1.1.1   rJava_1.0-11
# [7] repr_1.1.7
#
# loaded via a namespace (and not attached):
#  [1] dotCall64_1.2           spam_2.11-0             latticeExtra_0.6-30
#  [4] lattice_0.22-6          vctrs_0.6.5             mapplots_1.5.2
#  [7] tools_4.3.3             bitops_1.0-9            generics_0.1.3
# [10] parallel_4.3.3          tibble_3.2.1            proxy_0.4-27
# [13] fansi_1.0.6             SpecsVerification_0.5-3 pkgconfig_2.0.3
# [16] data.table_1.15.4       RColorBrewer_1.1-3      uuid_1.2-1
# [19] lifecycle_1.0.4         compiler_4.3.3          kohonen_3.0.12
# [22] deldir_2.0-4            fields_16.3             munsell_0.5.1
# [25] akima_0.6-3.4           htmltools_0.5.8.1       maps_3.4.2
# [28] RCurl_1.98-1.16         pillar_1.9.0            crayon_1.5.3
# [31] MASS_7.3-60.0.1         boot_1.3-31             abind_1.4-5
# [34] vioplot_0.5.0           padr_0.6.2              verification_1.42
# [37] tidyselect_1.2.1        digest_0.6.37           dplyr_1.1.4
# [40] fastmap_1.2.0           grid_4.3.3              colorspace_2.1-1
# [43] cli_3.6.3               magrittr_2.0.3          base64enc_0.1-3
# [46] utf8_1.2.4              sm_2.2-6.0              IRdisplay_1.1
# [49] withr_3.0.2             scales_1.3.0            sp_2.1-4
# [52] IRkernel_1.3.2          jpeg_0.1-10             interp_1.1-6
# [55] pbdZMQ_0.3-13           RcppEigen_0.3.4.0.2     zoo_1.8-12
# [58] png_0.1-8               pbapply_1.7-2           evaluate_1.0.1
# [61] dtw_1.23-1              viridisLite_0.4.2       rlang_1.1.4
# [64] Rcpp_1.0.13-1           glue_1.8.0              easyVerification_0.4.5
# [67] CircStats_0.2-6         jsonlite_1.8.9          R6_2.5.1
